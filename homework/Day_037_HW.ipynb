# %% [markdown]
# ## 作業
# 在鐵達尼資料集中，
# 透過進階補值方法 KNN，將鐵達尼號中的 Titanic_train
# .csv 中的 age 的遺失值進行補值。
# * step1: 觀察 Age 和 Pclass 與 Sex 是否有關連性?
# * step2: 如果有關連性，運用 KNN ，取出 Age 、 Pclass、 Sex的資料，以 Sex 與 Pclass 補 Age 遺失值。

# %%
# import library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import math
import statistics
import seaborn as sns
from IPython.display import display

# %% [markdown]
# ## 讀入資料

# %%
Titanic_data = pd.read_csv('C:/Users/Sue Lin/ML100Days/EDA/Titanic_train.csv')  
Titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## 觀察 Age

# %%
Titanic_data['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
missing_vals = Titanic_data.isnull().sum()/len(Titanic_data)
missing_vals.sort_values(ascending=False)
missing_vals = pd.DataFrame(missing_vals,columns=['missing_rate'])
print(missing_vals)
# Out:
#              missing_rate
# PassengerId      0.000000
# Survived         0.000000
# Pclass           0.000000
# Name             0.000000
# Sex              0.000000
# Age              0.198653
# SibSp            0.000000
# Parch            0.000000
# Ticket           0.000000
# Fare             0.000000
# Cabin            0.771044
# Embarked         0.002245

# %%
g = sns.catplot(x="Sex", y="Age", hue="Sex",
               data=Titanic_data,kind="box")

# %%
g = sns.catplot(x="Sex", y="Pclass", hue="Sex",
               data=Titanic_data,kind="box")

# %%
g = sns.regplot(x="Age", y="Pclass", color="g",data=Titanic_data)

# %%
g = sns.regplot(x="Fare", y="Pclass", color="g",data=Titanic_data)

# %%
g = sns.catplot("Pclass",'Age',
                data=Titanic_data,
                kind="box", height=2.5, aspect=.8)
# Out:
# c:\users\sue lin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
missing_index=Titanic_data.isnull()
display(Titanic_data[missing_index.values==True])
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 5              6         0       3                          Moran, Mr. James
# ..           ...       ...     ...                                       ...
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
data1=Titanic_data.copy()

# %%
data1 = data1[['Pclass','Sex','Age']]
from sklearn import preprocessing
#下面兩行程式，讓 Male=1, FeMale-0.
le = preprocessing.LabelEncoder()
data1['Sex']=le.fit_transform(data1['Sex'])
display(data1)
# Out:
#      Pclass  Sex   Age
# 0         3    1  22.0
# 1         1    0  38.0
# 2         3    0  26.0
# 3         1    0  35.0
# 4         3    1  35.0
# ..      ...  ...   ...
# 886       2    1  27.0
# 887       1    0  19.0
# 888       3    0   NaN
# 889       1    1  26.0
# 890       3    1  32.0
#
# [891 rows x 3 columns]

# %%
missing_index=data1.isnull()
display(data1[missing_index.values==True])
# Out:
#      Pclass  Sex  Age
# 5         3    1  NaN
# 17        2    1  NaN
# 19        3    0  NaN
# 26        3    1  NaN
# 28        3    0  NaN
# ..      ...  ...  ...
# 859       3    1  NaN
# 863       3    0  NaN
# 868       3    1  NaN
# 878       3    1  NaN
# 888       3    0  NaN
#
# [177 rows x 3 columns]

# %%
from sklearn.metrics.pairwise import nan_euclidean_distances
display(pd.DataFrame(nan_euclidean_distances(data1)))
# Out:
#            0          1          2          3          4         5    \
# 0     0.000000  16.155494   4.123106  13.190906  13.000000  0.000000
# 1    16.155494   0.000000  12.165525   3.000000   3.741657  2.738613
# 2     4.123106  12.165525   0.000000   9.219544   9.055385  1.224745
# 3    13.190906   3.000000   9.219544   0.000000   2.236068  2.738613
# 4    13.000000   3.741657   9.055385   2.236068   0.000000  0.000000
# ..         ...        ...        ...        ...        ...       ...
# 886   5.099020  11.090537   1.732051   8.124038   8.062258  1.224745
# 887   3.741657  19.000000   7.280110  16.000000  16.155494  2.738613
# 888   1.224745   2.449490   0.000000   2.449490   1.224745  1.224745
# 889   4.472136  12.041595   2.236068   9.055385   9.219544  2.449490
# 890  10.000000   6.403124   6.082763   3.741657   3.000000  0.000000
#
#            6          7          8          9    ...        881        882  \
# ...

# %%
# KNN
# 設定 k 值
value_neighbors=1
from sklearn.impute import KNNImputer
#初始化: Initialize KNNImputer
imputer = KNNImputer(n_neighbors=value_neighbors,add_indicator= True)
df_filled = pd.DataFrame(imputer.fit_transform(data1))
#display(data[missing_index.values==True])
#display(df_filled[missing_index.values==True])
display(df_filled)
# Out:
#        0    1     2    3
# 0    3.0  1.0  22.0  0.0
# 1    1.0  0.0  38.0  0.0
# 2    3.0  0.0  26.0  0.0
# 3    1.0  0.0  35.0  0.0
# 4    3.0  1.0  35.0  0.0
# ..   ...  ...   ...  ...
# 886  2.0  1.0  27.0  0.0
# 887  1.0  0.0  19.0  0.0
# 888  3.0  0.0  26.0  1.0
# 889  1.0  1.0  26.0  0.0
# 890  3.0  1.0  32.0  0.0
#
# [891 rows x 4 columns]

# %%
df_filled.loc[df_filled[3] == 1.0]
#0=Pclass;1=Sex;2=Age
# Out:
#        0    1     2    3
# 5    3.0  1.0  22.0  1.0
# 17   2.0  1.0  35.0  1.0
# 19   3.0  0.0  26.0  1.0
# 26   3.0  1.0  22.0  1.0
# 28   3.0  0.0  26.0  1.0
# ..   ...  ...   ...  ...
# 859  3.0  1.0  22.0  1.0
# 863  3.0  0.0  26.0  1.0
# 868  3.0  1.0  22.0  1.0
# 878  3.0  1.0  22.0  1.0
# 888  3.0  0.0  26.0  1.0
#
# [177 rows x 4 columns]

# %%
df_filled.loc[(df_filled[3] == 1.0) & (df_filled[1] == 1.0)]
#K=1時，男補值 = 3等艙22歲; 2等艙35歲;1等艙54歲
# Out:
#        0    1     2    3
# 5    3.0  1.0  22.0  1.0
# 17   2.0  1.0  35.0  1.0
# 26   3.0  1.0  22.0  1.0
# 29   3.0  1.0  22.0  1.0
# 36   3.0  1.0  22.0  1.0
# ..   ...  ...   ...  ...
# 839  1.0  1.0  54.0  1.0
# 846  3.0  1.0  22.0  1.0
# 859  3.0  1.0  22.0  1.0
# 868  3.0  1.0  22.0  1.0
# 878  3.0  1.0  22.0  1.0
#
# [124 rows x 4 columns]

# %%
df_filled.loc[(df_filled[1] == 0.0) & (df_filled[3] == 1.0)]
#K=1時，女補值 = 3等艙26歲; 2等艙14歲;1等艙38歲
# Out:
#        0    1     2    3
# 19   3.0  0.0  26.0  1.0
# 28   3.0  0.0  26.0  1.0
# 31   1.0  0.0  38.0  1.0
# 32   3.0  0.0  26.0  1.0
# 47   3.0  0.0  26.0  1.0
# 82   3.0  0.0  26.0  1.0
# 109  3.0  0.0  26.0  1.0
# 128  3.0  0.0  26.0  1.0
# 140  3.0  0.0  26.0  1.0
# 166  1.0  0.0  38.0  1.0
# 180  3.0  0.0  26.0  1.0
# 186  3.0  0.0  26.0  1.0
# 198  3.0  0.0  26.0  1.0
# 229  3.0  0.0  26.0  1.0
# 235  3.0  0.0  26.0  1.0
# 240  3.0  0.0  26.0  1.0
# 241  3.0  0.0  26.0  1.0
# 256  1.0  0.0  38.0  1.0
# 264  3.0  0.0  26.0  1.0
# 274  3.0  0.0  26.0  1.0
# 300  3.0  0.0  26.0  1.0
# 303  2.0  0.0  14.0  1.0
# 306  1.0  0.0  38.0  1.0
# 330  3.0  0.0  26.0  1.0
# 334  1.0  0.0  38.0  1.0
# 347  3.0  0.0  26.0  1.0
# 358  3.0  0.0  26.0  1.0
# 359  3.0  0.0  26.0  1.0
# 367  3.0  0.0  26.0  1.0
# 368  3.0  0.0  26.0  1.0
# 375  1.0  0.0  38.0  1.0
# 409  3.0  0.0  26.0  1.0
# 415  3.0  0.0  26.0  1.0
# 431  3.0  0.0  26.0  1.0
# 457  1.0  0.0  38.0  1.0
# 485  3.0  0.0  26.0  1.0
# ...
